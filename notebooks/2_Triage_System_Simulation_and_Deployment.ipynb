# %%
# ==============================================================================
#                 CELL 1: COMPLETE PROJECT SETUP (FINAL)
# ------------------------------------------------------------------------------
# Purpose: This single cell handles all setup: mounting, paths, libraries,
#          and imports to ensure the environment is correctly configured.
# ==============================================================================
import os
from google.colab import drive

# --- 1. Mounting and Paths ---
print("📁 Mounting Google Drive...")
drive.mount('/content/drive')

# IMPORTANT: Verify this is the correct folder name!
BASE_PROJECT_PATH = '/content/drive/MyDrive/brain-tumor/'
# If your folder is named 'brain-tumor (1)', change the line above to:
# BASE_PROJECT_PATH = '/content/drive/MyDrive/brain-tumor (1)/'

assert os.path.exists(BASE_PROJECT_PATH), f"Error: The path '{BASE_PROJECT_PATH}' does not exist. Please check the folder name."
print(f"✅ Project path verified: {BASE_PROJECT_PATH}")

# --- 2. Install and Import All Libraries ---
print("\n📦 Installing all necessary libraries...")
# FIX: Added streamlit and pyngrok to the installation
# !pip install -q ultralytics streamlit pyngrok

import pickle
import numpy as np
import pandas as pd
import torch
import cv2
from ultralytics import YOLO
from collections import Counter
from google.colab import files
import glob

print("✅ All libraries installed and imported successfully.")
# Out:
# 📁 Mounting Google Drive...
# Mounted at /content/drive
# ✅ Project path verified: /content/drive/MyDrive/brain-tumor/
#
# 📦 Installing all necessary libraries...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 68.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 85.0 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ All libraries installed and imported successfully.

# %%
# ==============================================================================
#      CELL 2: LOAD TRAINED MODEL AND CALIBRATED PREDICTIONS (CORRECTED)
# ------------------------------------------------------------------------------
# Purpose: Load assets from Phase 2 and define all necessary helper functions.
# ==============================================================================

# --- Load the saved test set predictions ---
try:
    TEST_DATA_PATH = os.path.join(BASE_PROJECT_PATH, 'Project_Clinically_Aware_AI/all_detections_data_TEST.pkl')
    with open(TEST_DATA_PATH, 'rb') as f:
        all_detections_data_TEST = pickle.load(f)
    print(f"✅ Successfully loaded {len(all_detections_data_TEST)} pre-computed detections from the test set.")
except FileNotFoundError:
    print(f"❌ ERROR: Could not find the test data file at '{TEST_DATA_PATH}'. Please ensure the path is correct.")


# --- Helper functions to get the context key ---
CLASS_NAMES = ['glioma', 'meningioma', 'no-tumor', 'pituitary']
TUMOR_SIZE_THRESHOLD = 0.0925

# --- NEW: ALL HELPER FUNCTIONS ARE NOW DEFINED HERE ---

def get_image_sharpness(image_array_grayscale):
    """Calculates image sharpness using the variance of the Laplacian."""
    if image_array_grayscale is None:
        return 0
    return cv2.Laplacian(image_array_grayscale, cv2.CV_64F).var()

def get_box_area(box):
    area = (box[2] - box[0]) * (box[3] - box[1])
    return area / (640 * 640)

def get_box_location(box):
    center_x = (box[0] + box[2]) / 2
    return 'Center' if (640 / 3 < center_x < 2 * 640 / 3) else 'Side'

def get_clinical_context_key(p):
    quality = "HighQuality" if p['sharpness'] > 33.02 else "LowQuality"
    class_name = CLASS_NAMES[p['class_id']].replace('-', '')
    size = "Large" if get_box_area(p['box']) > TUMOR_SIZE_THRESHOLD else "Small"
    location = get_box_location(p['box'])
    return f"{quality}_{class_name}_{size}_{location}"

# --- Re-create the calibrated predictions from your 32-group strategy ---
super_hybrid_temps = {
    'HighQuality_glioma_Small_Center': 0.4279, 'HighQuality_glioma_Small_Side': 1.6735,
    'HighQuality_meningioma_Large_Center': 0.1527, 'HighQuality_meningioma_Large_Side': 0.1985,
    'HighQuality_meningioma_Small_Center': 0.6029, 'HighQuality_meningioma_Small_Side': 0.0026,
    'HighQuality_notumor_Large_Center': 0.4716, 'HighQuality_pituitary_Small_Center': 0.0136,
    'LowQuality_glioma_Small_Center': 0.5259, 'LowQuality_glioma_Small_Side': 0.3803,
    'LowQuality_meningioma_Small_Center': 0.3721, 'LowQuality_meningioma_Small_Side': 0.3564,
    'LowQuality_notumor_Large_Center': 0.8852, 'LowQuality_pituitary_Small_Center': 0.4192
}

calibrated_predictions = []
for p in all_detections_data_TEST:
    context_key = get_clinical_context_key(p)
    temperature = super_hybrid_temps.get(context_key, 1.0)
    calibrated_conf = 1 / (1 + np.exp(-p['logit'] / temperature))
    final_prediction = p.copy()
    final_prediction['calibrated_confidence'] = calibrated_conf
    final_prediction['class_name'] = CLASS_NAMES[p['class_id']]
    calibrated_predictions.append(final_prediction)

print(f"✅ Generated {len(calibrated_predictions)} final calibrated predictions using your 32-group strategy.")
# Out:
# ✅ Successfully loaded 262 pre-computed detections from the test set.
# ✅ Generated 262 final calibrated predictions using your 32-group strategy.

# %%
# ==============================================================================
#                 CELL 3: DEFINE THE TRIAGE LOGIC
# ------------------------------------------------------------------------------
# Purpose: To define the rules-based engine that sorts cases into
#          clinical priority queues.
# ==============================================================================

def get_triage_category(prediction):
    """
    Sorts a single prediction into a clinical triage queue.

    Args:
        prediction (dict): A dictionary containing the calibrated prediction info,
                           including 'calibrated_confidence' and 'class_name'.

    Returns:
        tuple: A tuple containing the queue name (str) and a color code (str).
    """
    confidence = prediction['calibrated_confidence']
    class_name = prediction['class_name']

    # Rule 1: High-confidence "No-Tumor" cases are safe to fast-track
    if class_name == 'no-tumor' and confidence > 0.90:
        return "Green Queue (Routine Review)", "Green"

    # Rule 2: High-confidence tumor detections are urgent
    if class_name != 'no-tumor' and confidence > 0.90:
        return "Red Queue (Urgent Review)", "Red"

    # Rule 3: All other (lower confidence) cases require standard review
    return "Yellow Queue (Standard Review)", "Yellow"

print("✅ Triage logic function is defined and ready to use.")

# --- Test the function with a sample prediction ---
sample_prediction = calibrated_predictions[0] # Take the first prediction from our list
triage_queue, color = get_triage_category(sample_prediction)

print("\n--- Testing with a sample case ---")
print(f"Class: {sample_prediction['class_name']}, Calibrated Confidence: {sample_prediction['calibrated_confidence']:.3f}")
print(f"Assigned Triage Status: {triage_queue}")
# Out:
# ✅ Triage logic function is defined and ready to use.
#
# --- Testing with a sample case ---
# Class: pituitary, Calibrated Confidence: 1.000
# Assigned Triage Status: Red Queue (Urgent Review)

# %%
# ==============================================================================
#                 CELL 4: TRIAGE SIMULATION ON THE FULL TEST SET
# ------------------------------------------------------------------------------
# Purpose: To apply our triage logic to the entire test set and quantify
#          its potential impact on clinical workflow.
# ==============================================================================
from collections import Counter
import pandas as pd

print("🚀 Running full triage simulation on the test set...")

# A counter to store the number of cases in each queue
triage_counts = Counter()

# Lists to hold a few examples from each queue for review
green_examples = []
yellow_examples = []
red_examples = []

# Loop through every calibrated prediction from our test set
for prediction in calibrated_predictions:
    triage_queue, color = get_triage_category(prediction)

    # Increment the count for the assigned queue
    triage_counts[triage_queue] += 1

    # Save a few examples for inspection later
    if color == "Green" and len(green_examples) < 3:
        green_examples.append(prediction)
    elif color == "Yellow" and len(yellow_examples) < 3:
        yellow_examples.append(prediction)
    elif color == "Red" and len(red_examples) < 3:
        red_examples.append(prediction)

# --- Quantitative Analysis ---
total_predictions = len(calibrated_predictions)
results = []
for queue, count in triage_counts.items():
    percentage = (count / total_predictions) * 100
    results.append({
        "Triage Queue": queue,
        "Number of Cases": count,
        "Percentage of Workload": f"{percentage:.2f}%"
    })

results_df = pd.DataFrame(results)

print("\n" + "="*60)
print("--- 📊 TRIAGE SIMULATION RESULTS ---")
print("="*60)
print(results_df.to_string(index=False))

# --- Qualitative Analysis: Showcasing Examples ---
print("\n" + "="*60)
print("--- 📝 EXAMPLE CASE ASSIGNMENTS ---")
print("="*60)

print("\n🔴 Example of a 'Red Queue (Urgent Review)' case:")
if red_examples:
    p = red_examples[0]
    print(f"   - Predicted Class: {p['class_name']}")
    print(f"   - Calibrated Confidence: {p['calibrated_confidence']:.3f}")
else:
    print("   - No cases were assigned to the Red Queue in this run.")

print("\n🟡 Example of a 'Yellow Queue (Standard Review)' case:")
if yellow_examples:
    p = yellow_examples[0]
    print(f"   - Predicted Class: {p['class_name']}")
    print(f"   - Calibrated Confidence: {p['calibrated_confidence']:.3f}")
else:
    print("   - No cases were assigned to the Yellow Queue in this run.")

print("\n🟢 Example of a 'Green Queue (Routine Review)' case:")
if green_examples:
    p = green_examples[0]
    print(f"   - Predicted Class: {p['class_name']}")
    print(f"   - Calibrated Confidence: {p['calibrated_confidence']:.3f}")
else:
    print("   - No cases were assigned to the Green Queue in this run.")
# Out:
# 🚀 Running full triage simulation on the test set...
#
# ============================================================
# --- 📊 TRIAGE SIMULATION RESULTS ---
# ============================================================
#                   Triage Queue  Number of Cases Percentage of Workload
#      Red Queue (Urgent Review)              134                 51.15%
# Yellow Queue (Standard Review)               95                 36.26%
#   Green Queue (Routine Review)               33                 12.60%
#
# ============================================================
# --- 📝 EXAMPLE CASE ASSIGNMENTS ---
# ============================================================
#
# 🔴 Example of a 'Red Queue (Urgent Review)' case:
#    - Predicted Class: pituitary
#    - Calibrated Confidence: 1.000
#
# 🟡 Example of a 'Yellow Queue (Standard Review)' case:
#    - Predicted Class: glioma
#    - Calibrated Confidence: 0.881
#
# 🟢 Example of a 'Green Queue (Routine Review)' case:
#    - Predicted Class: no-tumor
#    - Calibrated Confidence: 0.975

# %%
# ==============================================================================
#                      NEW CELL 5: DEBUG LAUNCHER
# ------------------------------------------------------------------------------
# Purpose: To run the Streamlit app in the foreground to expose any
#          hidden startup errors and their tracebacks.
# ==============================================================================

# !streamlit run app.py
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.91.205.128:8501
#
#   Stopping...
# Traceback (most recent call last):
#   File "/usr/local/bin/streamlit", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1442, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1363, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1830, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1226, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 794, in invoke
#     return callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/cli.py", line 237, in main_run
#     _main_run(target, args, flag_options=kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/cli.py", line 279, in _main_run
#     bootstrap.run(file, is_hello, args, flag_options)
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/bootstrap.py", line 363, in run
#     asyncio.run(main())
#   File "/usr/lib/python3.12/asyncio/runners.py", line 195, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 678, in run_until_complete
#     self.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1961, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/bootstrap.py", line 43, in signal_handler
#     server.stop()
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/server/server.py", line 508, in stop
#     cli_util.print_to_cli("  Stopping...", fg="blue")
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/cli_util.py", line 35, in print_to_cli
#     click.secho(message, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/click/termui.py", line 684, in secho
#     return echo(message, file=file, nl=nl, err=err, color=color)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/utils.py", line 321, in echo
#     file.write(out)  # type: ignore
#     ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/bootstrap.py", line 43, in signal_handler
#     server.stop()
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/server/server.py", line 508, in stop
#     cli_util.print_to_cli("  Stopping...", fg="blue")
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/cli_util.py", line 35, in print_to_cli
#     click.secho(message, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/click/termui.py", line 684, in secho
#     return echo(message, file=file, nl=nl, err=err, color=color)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/utils.py", line 321, in echo
#     file.write(out)  # type: ignore
#     ^^^^^^^^^^^^^^^
# RuntimeError: reentrant call inside <_io.BufferedWriter name='<stdout>'>

# %%
# ==============================================================================
#                 CELL 6: DEPLOY APP WITH NGROK (ROBUST METHOD)
# ------------------------------------------------------------------------------
# Purpose: To reliably launch the Streamlit app using ngrok, which is
#          more stable than Colab's default external URL.
# ==============================================================================

# --- 1. Install pyngrok ---
# !pip install -q pyngrok

# --- 2. Paste your ngrok authtoken here ---
# Replace the placeholder text with the token you copied from your ngrok dashboard.
NGROK_AUTH_TOKEN = "32odaMtz4LNdW98afCIIR99PXY1_6Fiy6CUW2TeU5RqQbcafX"

# --- 3. The Code to Launch the App ---
import os
import threading
import time
from pyngrok import ngrok

# Authenticate ngrok
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Kill any existing streamlit or ngrok processes
# !killall streamlit
# !killall ngrok
time.sleep(2)

# Function to run streamlit in the background
def run_streamlit():
    os.system("streamlit run app.py --server.headless true --server.enableCORS false")

# Start streamlit in a new thread
thread = threading.Thread(target=run_streamlit)
thread.start()
time.sleep(5) # Give streamlit a moment to start

# Open a tunnel to the streamlit port (8501)
public_url = ngrok.connect(8501)
print("="*50)
print("✅ Your app is now live and running!")
print(f"🚀 Click this Public URL to open your app: {public_url}")
print("="*50)
# Out:
# streamlit: no process found
# ngrok: no process found
# ==================================================
# ✅ Your app is now live and running!
# 🚀 Click this Public URL to open your app: NgrokTunnel: "https://a1c2acbc5c2a.ngrok-free.app" -> "http://localhost:8501"
# ==================================================

# %%
# ==============================================================================
#                 CELL 7: FIND AND DOWNLOAD TEST IMAGES
# ------------------------------------------------------------------------------
# Purpose: To automatically find ideal images for each triage test case
#          and download them from Google Drive to your local computer.
# ==============================================================================
from google.colab import files
import glob

print("🔎 Searching for ideal test case images in your validation set...")

# --- 1. Define search parameters and the image directory ---
VALIDATION_IMAGE_DIR = os.path.join(BASE_PROJECT_PATH, 'Project_Clinically_Aware_AI/dataset_setup/validation_images/')

# We will store the paths to the best images we find
image_paths_to_download = {}

# --- 2. Iterate through files to find our test cases ---
# We'll grab all .jpg files from the directory
all_images = glob.glob(os.path.join(VALIDATION_IMAGE_DIR, "*.jpg"))

for image_path in all_images:
    filename = os.path.basename(image_path)

    # We need to calculate sharpness to find high/low quality images
    # The get_image_sharpness function is already in memory from our setup
    img_gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    sharpness = get_image_sharpness(img_gray)

    # Test Case 1: Find a high-quality "no-tumor" scan for the Green Queue
    if "green_queue_test" not in image_paths_to_download and filename.startswith("Tr-no_") and sharpness > 100:
        image_paths_to_download["green_queue_test.jpg"] = image_path
        print(f"  - Found Green Queue example: {filename} (Sharpness: {sharpness:.2f})")

    # Test Case 2: Find a clear, high-quality "meningioma" for the Red Queue
    if "red_queue_test" not in image_paths_to_download and filename.startswith("Tr-me_") and sharpness > 100:
        image_paths_to_download["red_queue_test.jpg"] = image_path
        print(f"  - Found Red Queue example: {filename} (Sharpness: {sharpness:.2f})")

    # Test Case 3: Find a low-quality "glioma" for the Yellow Queue
    if "yellow_queue_test" not in image_paths_to_download and filename.startswith("Tr-gl_") and sharpness < 40:
        image_paths_to_download["yellow_queue_test.jpg"] = image_path
        print(f"  - Found Yellow Queue example: {filename} (Sharpness: {sharpness:.2f})")

    # Stop searching once we have found one of each
    if len(image_paths_to_download) == 3:
        break

# --- 3. Download the selected files to your local machine ---
print("\n⬇️ Preparing to download the 3 test images to your computer...")

if not image_paths_to_download:
    print("⚠️ Could not find suitable images for all test cases. Please check the directory path.")
else:
    for new_name, original_path in image_paths_to_download.items():
        # Copy the file to the local Colab session with a simpler name first
        # !cp "{original_path}" ./{new_name}
        # Trigger the browser download
        files.download(new_name)
    print("\n✅ Download complete! Check your browser's download bar.")
# Out:
# 🔎 Searching for ideal test case images in your validation set...
#   - Found Yellow Queue example: Tr-gl_0011_jpg.rf.c6586a6320264a828625b45ba88fabac.jpg (Sharpness: 34.90)
#   - Found Yellow Queue example: Tr-gl_0302_jpg.rf.0d359f595d6641267c9dfcec1c97c4ae.jpg (Sharpness: 30.19)
#   - Found Yellow Queue example: Tr-gl_0310_jpg.rf.55b2520296336ec2735cb44f5650d53d.jpg (Sharpness: 13.93)
#   - Found Yellow Queue example: Tr-gl_0221_jpg.rf.2d2ec67a535c9b74acc29713603d76c0.jpg (Sharpness: 12.85)
#   - Found Yellow Queue example: Tr-gl_0057_jpg.rf.00db06a404574ba14346d9a5416f878f.jpg (Sharpness: 19.51)
#   - Found Yellow Queue example: Tr-gl_0175_jpg.rf.c61d1aed455e8185a1e8925785b4480a.jpg (Sharpness: 12.62)
#   - Found Yellow Queue example: Tr-gl_0015_jpg.rf.f19712315a693c8362217ca980843f70.jpg (Sharpness: 30.90)
#   - Found Yellow Queue example: Tr-gl_0014_jpg.rf.b717ae199e12230bf44b56eba9d741b1.jpg (Sharpness: 38.26)
#   - Found Yellow Queue example: Tr-gl_0018_jpg.rf.32814a3e780f52883d520898ecedfb4c.jpg (Sharpness: 20.55)
#   - Found Yellow Queue example: Tr-gl_0020_jpg.rf.fcbf996caf74ebc28e7401df1dd06f7f.jpg (Sharpness: 39.00)
#   - Found Yellow Queue example: Tr-gl_0022_jpg.rf.829d7981e97aa2778a67a60119cf4d9d.jpg (Sharpness: 31.11)
#   - Found Yellow Queue example: Tr-gl_0027_jpg.rf.d63802cc0fc0610692a37a49e3ce439d.jpg (Sharpness: 33.73)
#   - Found Yellow Queue example: Tr-gl_0031_jpg.rf.77c2535409295eda4ce4127ab5aebfa3.jpg (Sharpness: 17.92)
#   - Found Yellow Queue example: Tr-gl_0031_jpg.rf.ee8bfd631d02a47753fffaceddd313f3.jpg (Sharpness: 17.93)
#   - Found Yellow Queue example: Tr-gl_0036_jpg.rf.d2c4e7f0d9af61e05f019c568bf7c12c.jpg (Sharpness: 22.60)
#   - Found Yellow Queue example: Tr-gl_0043_jpg.rf.18703231992f36c064d5db4d1af3b5de.jpg (Sharpness: 24.73)
#   - Found Yellow Queue example: Tr-gl_0048_jpg.rf.0bfa6be7a00fae71eb3496f55017ce48.jpg (Sharpness: 23.54)
#   - Found Yellow Queue example: Tr-gl_0052_jpg.rf.a44e2003e2cd4dbdec6743590a1f5124.jpg (Sharpness: 13.38)
#   - Found Yellow Queue example: Tr-gl_0036_jpg.rf.25563402c6f573f8750aa0e3e165d73e.jpg (Sharpness: 22.60)
#   - Found Yellow Queue example: Tr-gl_0051_jpg.rf.b04f3a9b9f83a6167a021b5cc8462fb3.jpg (Sharpness: 29.50)
#   - Found Yellow Queue example: Tr-gl_0054_jpg.rf.d6674c8411ae4e41529199c06df8b501.jpg (Sharpness: 17.47)
#   - Found Yellow Queue example: Tr-gl_0057_jpg.rf.825bc3f1fb9ca596ff8e35935507dfa6.jpg (Sharpness: 19.50)
#   - Found Yellow Queue example: Tr-gl_0058_jpg.rf.25805b72caaba6f3ef03914f77706fcd.jpg (Sharpness: 20.33)
#   - Found Yellow Queue example: Tr-gl_0059_jpg.rf.fef35209b8d752266b21a98bde28487b.jpg (Sharpness: 25.98)
#   - Found Yellow Queue example: Tr-gl_0064_jpg.rf.fe67bb78e6a3f3599250212676f80cf7.jpg (Sharpness: 33.90)
#   - Found Yellow Queue example: Tr-gl_0064_jpg.rf.0fc8033323aca695bf9aaf8a7ff9af21.jpg (Sharpness: 33.90)
#   - Found Yellow Queue example: Tr-gl_0066_jpg.rf.74c5e2266c026aa0bcce72a2c876afe0.jpg (Sharpness: 14.52)
#   - Found Yellow Queue example: Tr-gl_0066_jpg.rf.2c55f529cecd4c090b56060f0cdf48d7.jpg (Sharpness: 14.52)
#   - Found Yellow Queue example: Tr-gl_0068_jpg.rf.f55c7bab29623c68c0479bd7ad67f6a8.jpg (Sharpness: 38.06)
#   - Found Yellow Queue example: Tr-gl_0071_jpg.rf.c201d87564a1cc43f00d6dda444fe396.jpg (Sharpness: 16.08)
#   - Found Yellow Queue example: Tr-gl_0072_jpg.rf.317d736b2daced96c4bb766c0ed11229.jpg (Sharpness: 22.99)
#   - Found Yellow Queue example: Tr-gl_0073_jpg.rf.a01d82d2535c0fc1c6a7673d0cde6cbb.jpg (Sharpness: 32.27)
#   - Found Yellow Queue example: Tr-gl_0078_jpg.rf.00aabf2032db6b833dd24f8cb2a3dd4b.jpg (Sharpness: 24.61)
#   - Found Yellow Queue example: Tr-gl_0081_jpg.rf.266d6604f10680e16415459d6fb51388.jpg (Sharpness: 27.34)
#   - Found Yellow Queue example: Tr-gl_0084_jpg.rf.d86ea7c99a8c0936600e2897a5d66c44.jpg (Sharpness: 12.08)
#   - Found Yellow Queue example: Tr-gl_0080_jpg.rf.9cdddc00b5b5d9642aa1f90560e936bc.jpg (Sharpness: 22.03)
#   - Found Yellow Queue example: Tr-gl_0096_jpg.rf.cea0f0e567f962a034cf7fbc788f13e7.jpg (Sharpness: 29.06)
#   - Found Yellow Queue example: Tr-gl_0096_jpg.rf.0c4ed8b1147d2517bda3a502e498a969.jpg (Sharpness: 29.07)
#   - Found Yellow Queue example: Tr-gl_0100_jpg.rf.026d3a706ebdb382122954bb8e7004d8.jpg (Sharpness: 30.31)
#   - Found Yellow Queue example: Tr-gl_0110_jpg.rf.c786fdc2a863b045981db44b091fd4f4.jpg (Sharpness: 27.66)
#   - Found Yellow Queue example: Tr-gl_0114_jpg.rf.2d6ada67ca4a70d5c4003f43ac11529a.jpg (Sharpness: 16.06)
#   - Found Yellow Queue example: Tr-gl_0115_jpg.rf.a781d54f0285714f3a376557d1e28e15.jpg (Sharpness: 25.78)
#   - Found Yellow Queue example: Tr-gl_0116_jpg.rf.a30253abd9b7184e13b705b17f143bd3.jpg (Sharpness: 23.98)
#   - Found Yellow Queue example: Tr-gl_0118_jpg.rf.3257922862c884342127cdc1ca02f322.jpg (Sharpness: 24.89)
#   - Found Yellow Queue example: Tr-gl_0119_jpg.rf.81eaa74526437ee77525aeaf20708b34.jpg (Sharpness: 17.11)
#   - Found Yellow Queue example: Tr-gl_0120_jpg.rf.3e2a51b04a8e21e42b72a547dd83d28b.jpg (Sharpness: 34.80)
#   - Found Yellow Queue example: Tr-gl_0123_jpg.rf.9d9f5d055b1e519033a08a4e6882b455.jpg (Sharpness: 23.23)
#   - Found Yellow Queue example: Tr-gl_0133_jpg.rf.caa945cf13b97c782d86d61d8c236701.jpg (Sharpness: 22.30)
#   - Found Yellow Queue example: Tr-gl_0136_jpg.rf.477caffa816bf58d20ad8de068f9c7e3.jpg (Sharpness: 21.92)
#   - Found Yellow Queue example: Tr-gl_0141_jpg.rf.1823a2219d44ccf5c78461626824f72d.jpg (Sharpness: 37.48)
#   - Found Yellow Queue example: Tr-gl_0138_jpg.rf.e8214f03282d69d7d7f0dfe48b898374.jpg (Sharpness: 18.01)
#   - Found Yellow Queue example: Tr-gl_0142_jpg.rf.4c20f26f06dfb7ac3dd4fb22360ea37a.jpg (Sharpness: 20.61)
#   - Found Yellow Queue example: Tr-gl_0143_jpg.rf.12ef591d0caeddfd7e1a87afecc9827b.jpg (Sharpness: 21.33)
#   - Found Yellow Queue example: Tr-gl_0144_jpg.rf.07248a5949c97ff634dd2e87004ef5d2.jpg (Sharpness: 16.60)
#   - Found Yellow Queue example: Tr-gl_0152_jpg.rf.6fedf013fdcb20b060ec336972fcc069.jpg (Sharpness: 20.17)
#   - Found Yellow Queue example: Tr-gl_0152_jpg.rf.7083ccfd4be796ed6c17d072a9aba4b5.jpg (Sharpness: 20.18)
#   - Found Yellow Queue example: Tr-gl_0154_jpg.rf.709e7acdb2b4f84d4db251d5763e0b28.jpg (Sharpness: 17.18)
#   - Found Yellow Queue example: Tr-gl_0156_jpg.rf.5a64a3bdbbe5059b3ebed99cf2fbd2ca.jpg (Sharpness: 14.79)
#   - Found Yellow Queue example: Tr-gl_0166_jpg.rf.23d0800b3fc6923736d5ec128b8e8668.jpg (Sharpness: 12.74)
#   - Found Yellow Queue example: Tr-gl_0170_jpg.rf.d7ecf1aa90073f4f297a60c3aa98585c.jpg (Sharpness: 33.01)
#   - Found Yellow Queue example: Tr-gl_0178_jpg.rf.5e171245ad03ef1fe2f563aaad85e2f0.jpg (Sharpness: 31.20)
#   - Found Yellow Queue example: Tr-gl_0179_jpg.rf.891163d4df8ff2cbe3ad7074bdf30cbf.jpg (Sharpness: 32.00)
#   - Found Yellow Queue example: Tr-gl_0179_jpg.rf.eb8af02e676d544b34b752a52b129fec.jpg (Sharpness: 32.00)
#   - Found Yellow Queue example: Tr-gl_0193_jpg.rf.6f4e56ff02a062d37add5507f6c921d8.jpg (Sharpness: 35.97)
#   - Found Yellow Queue example: Tr-gl_0202_jpg.rf.3c8e0fde4be86affaede80d76afdd7ef.jpg (Sharpness: 39.75)
#   - Found Yellow Queue example: Tr-gl_0200_jpg.rf.693cd511964a3a1887333638f40a6611.jpg (Sharpness: 36.33)
#   - Found Yellow Queue example: Tr-gl_0203_jpg.rf.b32a14e793e3ad3c9356aa38f29ad79a.jpg (Sharpness: 23.29)
#   - Found Yellow Queue example: Tr-gl_0207_jpg.rf.35b9c261964f0204c2df43f661ae35f9.jpg (Sharpness: 12.51)
#   - Found Yellow Queue example: Tr-gl_0210_jpg.rf.d60e5a2a3c687b95d10debe7a96434fb.jpg (Sharpness: 7.24)
#   - Found Yellow Queue example: Tr-gl_0209_jpg.rf.750ce6186bc3c463ae20c02fcbf361dc.jpg (Sharpness: 7.58)
#   - Found Yellow Queue example: Tr-gl_0213_jpg.rf.d5d06ff1cd74b5dd1e77077e59b6fdd2.jpg (Sharpness: 23.94)
#   - Found Yellow Queue example: Tr-gl_0217_jpg.rf.64beb1cdc0c3b60938cee29b98afb415.jpg (Sharpness: 10.56)
#   - Found Yellow Queue example: Tr-gl_0225_jpg.rf.4fe5b52df0437ad3f8387a167a685bd6.jpg (Sharpness: 30.41)
#   - Found Yellow Queue example: Tr-gl_0219_jpg.rf.6f887e27e4861d579f4e8601c83a23e9.jpg (Sharpness: 8.74)
#   - Found Yellow Queue example: Tr-gl_0218_jpg.rf.fd97093a0df5b78a07a2541937c315ba.jpg (Sharpness: 8.39)
#   - Found Yellow Queue example: Tr-gl_0239_jpg.rf.6e5cff37515b73707663e8ff1537460a.jpg (Sharpness: 16.43)
#   - Found Yellow Queue example: Tr-gl_0243_jpg.rf.e25a1d7197efb34f63da19bbfebedf33.jpg (Sharpness: 19.71)
#   - Found Yellow Queue example: Tr-gl_0245_jpg.rf.808e58cedd79711db379b4c5a21ed388.jpg (Sharpness: 15.27)
#   - Found Yellow Queue example: Tr-gl_0246_jpg.rf.9ea1a9b56d7792fc667244be87e9342d.jpg (Sharpness: 13.35)
#   - Found Yellow Queue example: Tr-gl_0251_jpg.rf.7e22cc428076ddb03ab887648b4fde52.jpg (Sharpness: 24.23)
#   - Found Yellow Queue example: Tr-gl_0252_jpg.rf.afabe695582b42201c2986c56caf131e.jpg (Sharpness: 17.85)
#   - Found Yellow Queue example: Tr-gl_0248_jpg.rf.03b8dd808fb25d263921d023d716b49c.jpg (Sharpness: 10.81)
#   - Found Yellow Queue example: Tr-gl_0246_jpg.rf.e555c6014b0a52a2ed024fbc42d0e95c.jpg (Sharpness: 13.35)
#   - Found Yellow Queue example: Tr-gl_0252_jpg.rf.e4418068dc02dc02f209448b26321764.jpg (Sharpness: 17.85)
#   - Found Yellow Queue example: Tr-gl_0253_jpg.rf.56d0db63cf5aac0969e820d4b5cc5bd2.jpg (Sharpness: 16.31)
#   - Found Yellow Queue example: Tr-gl_0294_jpg.rf.0aa8c2dd737d6fc088c894d13d202cc0.jpg (Sharpness: 24.12)
#   - Found Yellow Queue example: Tr-gl_0258_jpg.rf.404c22ac1e6913f9cf84c65102224e1e.jpg (Sharpness: 15.53)
#   - Found Yellow Queue example: Tr-gl_0313_jpg.rf.5a994a722de484cccbbac1092f63c3cf.jpg (Sharpness: 30.85)
#   - Found Yellow Queue example: Tr-gl_0311_jpg.rf.ea40dda73b6719fedfa6291a31d7d6db.jpg (Sharpness: 12.07)
#   - Found Yellow Queue example: Tr-gl_0294_jpg.rf.1c57851e22e937b624f1a5ccd812536c.jpg (Sharpness: 24.13)
#   - Found Yellow Queue example: Tr-gl_0316_jpg.rf.bddbbb7533ae718ee3443fe524dc4fe5.jpg (Sharpness: 24.01)
#   - Found Yellow Queue example: Tr-gl_0315_jpg.rf.e3d3139d7eddbfcadf36e8142b72f9e3.jpg (Sharpness: 27.23)
#   - Found Yellow Queue example: Tr-gl_0322_jpg.rf.58715ba6f49908df83f4d4dbe0370049.jpg (Sharpness: 19.94)
#   - Found Yellow Queue example: Tr-gl_0325_jpg.rf.350261eec368000bdb3016a91e79079f.jpg (Sharpness: 12.78)
#   - Found Yellow Queue example: Tr-gl_0325_jpg.rf.8127e0eaaf77ccb9b8152c9f6b96ae8e.jpg (Sharpness: 12.78)
#   - Found Yellow Queue example: Tr-gl_0328_jpg.rf.33a2b2410aa58fc8618eef05a686f421.jpg (Sharpness: 19.63)
#   - Found Yellow Queue example: Tr-gl_0327_jpg.rf.1b50ab9710a3a9773e2d463c66ca83c2.jpg (Sharpness: 31.27)
#   - Found Yellow Queue example: Tr-gl_0330_jpg.rf.ba4de1d56be291c3d65cce4fb9c8082b.jpg (Sharpness: 28.88)
#   - Found Yellow Queue example: Tr-gl_0335_jpg.rf.34c64799b0e8cba26604dcc6c4edeca2.jpg (Sharpness: 16.03)
#   - Found Yellow Queue example: Tr-gl_0333_jpg.rf.f874fba563cd3e860879a5955cdff5e0.jpg (Sharpness: 18.32)
#   - Found Yellow Queue example: Tr-gl_0336_jpg.rf.0033e4da8602472a4fe3495c455ff736.jpg (Sharpness: 15.93)
#   - Found Yellow Queue example: Tr-gl_0338_jpg.rf.37241c78ea36f6a06edb33e25488ffd0.jpg (Sharpness: 11.48)
#   - Found Yellow Queue example: Tr-gl_0341_jpg.rf.7736a41c4932ab063662889e647bd8fe.jpg (Sharpness: 19.56)
#   - Found Yellow Queue example: Tr-gl_0343_jpg.rf.b937fff65894b876e9bbaf7ca93e669f.jpg (Sharpness: 24.44)
#   - Found Yellow Queue example: Tr-gl_0369_jpg.rf.b8ece64c33c16eb84553edd6e1f680a6.jpg (Sharpness: 27.34)
#   - Found Yellow Queue example: Tr-gl_0371_jpg.rf.ff7f77a248ddb2c1bc815f260d0edb36.jpg (Sharpness: 27.26)
#   - Found Yellow Queue example: Tr-gl_0376_jpg.rf.02931eeaa4182ef084cb38e221eb2b52.jpg (Sharpness: 17.88)
#   - Found Yellow Queue example: Tr-gl_0375_jpg.rf.122db6215f7270b1c5ba89ee1e289e4b.jpg (Sharpness: 20.27)
#   - Found Yellow Queue example: Tr-gl_0377_jpg.rf.1112e4c5d328398454beeb2a4ff6d5ee.jpg (Sharpness: 9.77)
#   - Found Yellow Queue example: Tr-gl_0378_jpg.rf.237f0d39d9708e53948cce4ac822a235.jpg (Sharpness: 26.83)
#   - Found Yellow Queue example: Tr-gl_0379_jpg.rf.daead52855228ce5de29791d75e1f2ec.jpg (Sharpness: 28.89)
#   - Found Yellow Queue example: Tr-gl_0383_jpg.rf.929d9ea14810b02f36691adc3ee21fc6.jpg (Sharpness: 19.39)
#   - Found Yellow Queue example: Tr-gl_0380_jpg.rf.a125dbd9bbe7736a1415d9f25e2f1123.jpg (Sharpness: 25.23)
#   - Found Yellow Queue example: Tr-gl_0388_jpg.rf.ce70c61e3334354716bc3a77a642ee6b.jpg (Sharpness: 25.84)
#   - Found Yellow Queue example: Tr-gl_0394_jpg.rf.ad5d3ba2b46131e6000a51cb73d836ac.jpg (Sharpness: 21.32)
#   - Found Yellow Queue example: Tr-gl_0395_jpg.rf.b438a5bd6a5cf8e1bee50b4549960373.jpg (Sharpness: 16.41)
#   - Found Yellow Queue example: Tr-gl_0396_jpg.rf.e60763e0bb87f1773adff9c56164f1f2.jpg (Sharpness: 13.24)
#   - Found Yellow Queue example: Tr-gl_0399_jpg.rf.21066774527eb061e937df18ee4df157.jpg (Sharpness: 14.45)
#   - Found Yellow Queue example: Tr-gl_0406_jpg.rf.84338178fb782d538d8df645d48a0089.jpg (Sharpness: 27.08)
#   - Found Yellow Queue example: Tr-gl_0400_jpg.rf.7c4366f248ab5447069845ef3832bd98.jpg (Sharpness: 14.05)
#   - Found Yellow Queue example: Tr-gl_0411_jpg.rf.3c3b74fd8d205503162d1e740114abab.jpg (Sharpness: 20.96)
#   - Found Yellow Queue example: Tr-gl_0412_jpg.rf.5ca886d8ba4878cd1214f8ccfb617d6f.jpg (Sharpness: 14.94)
#   - Found Yellow Queue example: Tr-gl_0415_jpg.rf.d886fe2ccb7ebf567ab7fa6f9f2461e3.jpg (Sharpness: 14.39)
#   - Found Yellow Queue example: Tr-gl_0418_jpg.rf.7d770f96107de486829d3427c523f006.jpg (Sharpness: 20.34)
#   - Found Yellow Queue example: Tr-gl_0432_jpg.rf.ad3dd4ffcdfb2aa21aaa45f240c5c26e.jpg (Sharpness: 25.50)
#   - Found Yellow Queue example: Tr-gl_0417_jpg.rf.d16262079fa5b6f2fd62cd23d5b31fe4.jpg (Sharpness: 26.41)
#   - Found Yellow Queue example: Tr-gl_0433_jpg.rf.511224aaa8eafff63eef85661649aa3d.jpg (Sharpness: 33.03)
#   - Found Yellow Queue example: Tr-gl_0441_jpg.rf.fc834504109e95c6ce1ec7e959dfe8a6.jpg (Sharpness: 24.90)
#   - Found Yellow Queue example: Tr-gl_0437_jpg.rf.4171ef34aa4bdca7b9029ae22f6c806c.jpg (Sharpness: 22.94)
#   - Found Yellow Queue example: Tr-gl_0444_jpg.rf.e5026a49f17534bbb3cce50b8c8de219.jpg (Sharpness: 29.28)
#   - Found Yellow Queue example: Tr-gl_0448_jpg.rf.d588964e1370467e4fc07b29d115c249.jpg (Sharpness: 13.78)
#   - Found Yellow Queue example: Tr-gl_0457_jpg.rf.be9416cb2a28dca1205b00c6a622c704.jpg (Sharpness: 26.31)
#   - Found Yellow Queue example: Tr-gl_0451_jpg.rf.f25a418749b4524f40ae04f1a1041f09.jpg (Sharpness: 26.93)
#   - Found Yellow Queue example: Tr-gl_0464_jpg.rf.72714fd03fcd3e2b6f161e597e7bf35f.jpg (Sharpness: 22.18)
#   - Found Yellow Queue example: Tr-gl_0468_jpg.rf.0094630b64cdaa70221af2bd50bcd10a.jpg (Sharpness: 24.03)
#   - Found Yellow Queue example: Tr-gl_0469_jpg.rf.e16e21390b152a8e75885cb4842bcf0d.jpg (Sharpness: 25.59)
#   - Found Yellow Queue example: Tr-gl_0471_jpg.rf.d301e00165a080bd3a34204b89856a70.jpg (Sharpness: 22.92)
#   - Found Yellow Queue example: Tr-gl_0473_jpg.rf.0f42c3198b7a36f5bd2737b77c4e2c4c.jpg (Sharpness: 20.73)
#   - Found Yellow Queue example: Tr-gl_0473_jpg.rf.e9eb6e6447bf6554a2f9223f9df9de4a.jpg (Sharpness: 20.75)
#   - Found Yellow Queue example: Tr-gl_0474_jpg.rf.ecd6d8ae0f7f05808ddfffd016eee1e2.jpg (Sharpness: 23.68)
#   - Found Yellow Queue example: Tr-gl_0478_jpg.rf.05dd0366e773f8cd842bc5346243cb9b.jpg (Sharpness: 19.23)
#   - Found Yellow Queue example: Tr-gl_0487_jpg.rf.45849ab669d80f4a2c0882ad0c4e48cb.jpg (Sharpness: 24.10)
#   - Found Yellow Queue example: Tr-gl_0479_jpg.rf.7a092db6c4c8a0732c07757220c33fcf.jpg (Sharpness: 37.00)
#   - Found Yellow Queue example: Tr-gl_0488_jpg.rf.0ff4dda059e2ce126fe4fea1fccf27a1.jpg (Sharpness: 19.25)
#   - Found Yellow Queue example: Tr-gl_0503_jpg.rf.54cbc4af1375d3e24c418fbf1936ae90.jpg (Sharpness: 30.79)
#   - Found Yellow Queue example: Tr-gl_0491_jpg.rf.75b6ef129b26b1512e1b2cae44ad4452.jpg (Sharpness: 22.81)
#   - Found Yellow Queue example: Tr-gl_0504_jpg.rf.59a2acc5991906a4f21f01bee66fecde.jpg (Sharpness: 29.09)
#   - Found Yellow Queue example: Tr-gl_0531_jpg.rf.237c7083b7b23afb0fe81cbaebe27d1a.jpg (Sharpness: 24.37)
#   - Found Yellow Queue example: Tr-gl_0506_jpg.rf.51a4c03aff62f5c430ca9afaea83519c.jpg (Sharpness: 17.04)
#   - Found Yellow Queue example: Tr-gl_0508_jpg.rf.d6ddd0bf5f12a46e268d1adf574b03b9.jpg (Sharpness: 13.41)
#   - Found Yellow Queue example: Tr-gl_0533_jpg.rf.2cd5068dcdaf73625fc5378335a6a73d.jpg (Sharpness: 16.80)
#   - Found Yellow Queue example: Tr-gl_0540_jpg.rf.c6e8185b9a104e992b5f3bae71a88e0b.jpg (Sharpness: 33.12)
#   - Found Yellow Queue example: Tr-gl_0542_jpg.rf.be9509b1f16557c466a18cf7d49d71aa.jpg (Sharpness: 21.83)
#   - Found Yellow Queue example: Tr-gl_0543_jpg.rf.a5ee38fd2f8c51f904e4c5ceb4f1da4f.jpg (Sharpness: 19.59)
#   - Found Yellow Queue example: Tr-gl_0550_jpg.rf.667b7e2e928c9e4ac209da273de22135.jpg (Sharpness: 26.12)
#   - Found Yellow Queue example: Tr-gl_0559_jpg.rf.1d8d257bbcb800f2e59cbf1d4cbfc2ea.jpg (Sharpness: 16.86)
#   - Found Red Queue example: Tr-me_0179_jpg.rf.2da24ae0376b22eb189c369cfa4586c4.jpg (Sharpness: 135.11)
#   - Found Red Queue example: Tr-me_0209_jpg.rf.ff564d7038bf31ef47ad7a0c4867f2ee.jpg (Sharpness: 141.33)
#   - Found Red Queue example: Tr-me_0212_jpg.rf.f4bedb561f16c262755f595be47166cf.jpg (Sharpness: 174.59)
#   - Found Red Queue example: Tr-me_0241_jpg.rf.8e4031ea5439aebd0ec6911ac15f45e1.jpg (Sharpness: 239.56)
#   - Found Red Queue example: Tr-me_0252_jpg.rf.7730d0d8ad11ec2677b21d356c6df326.jpg (Sharpness: 328.52)
#   - Found Red Queue example: Tr-me_0253_jpg.rf.1378941a426aa30781eca18f8fe719ec.jpg (Sharpness: 145.20)
#   - Found Red Queue example: Tr-me_0259_jpg.rf.21f3db444d8c71136a5f06dbcc4f65cf.jpg (Sharpness: 109.12)
#   - Found Red Queue example: Tr-me_0260_jpg.rf.43e130ae6b0880cd55cf6e1b109d704b.jpg (Sharpness: 109.14)
#   - Found Red Queue example: Tr-me_0261_jpg.rf.46a7c78386440ee93bdac40e0b2c75ed.jpg (Sharpness: 448.46)
#   - Found Red Queue example: Tr-me_0263_jpg.rf.0d60c7a67d2c25f8d5886bb323509626.jpg (Sharpness: 125.09)
#   - Found Red Queue example: Tr-me_0274_jpg.rf.a1c5632886069df109b8786dd4839daa.jpg (Sharpness: 356.65)
#   - Found Red Queue example: Tr-me_0273_jpg.rf.e821f985136dc5ea5624c278c79c5036.jpg (Sharpness: 202.05)
#   - Found Red Queue example: Tr-me_0283_jpg.rf.94d48afd073d76c74d12a6c92df74d33.jpg (Sharpness: 383.96)
#   - Found Red Queue example: Tr-me_0335_jpg.rf.5696be3b17776bc7730831ef502ef380.jpg (Sharpness: 385.72)
#   - Found Red Queue example: Tr-me_0357_jpg.rf.50140f8b5c943f8c32a3a3a8f68a4654.jpg (Sharpness: 210.17)
#   - Found Red Queue example: Tr-me_0359_jpg.rf.5853939dbfd89bc00ae367d436cec78d.jpg (Sharpness: 317.26)
#   - Found Green Queue example: Tr-no_0010_jpg.rf.9e319159c1637f1abe205c42e8fbfdf2.jpg (Sharpness: 227.39)
#
# ⬇️ Preparing to download the 3 test images to your computer...
# ✅ Download complete! Check your browser's download bar.

# %%
# ==============================================================================
#                 CELL 8: CREATE COMPREHENSIVE TEST SET
# ------------------------------------------------------------------------------
# Purpose: To find and download 12 diverse images, including out-of-distribution
#          metastasis cases, for a final, rigorous system test.
# ==============================================================================
from google.colab import files
import glob
import random

print("🔎 Assembling a comprehensive test set of 12 images...")

# --- 1. Define paths to both datasets ---
VALIDATION_IMAGE_DIR = os.path.join(BASE_PROJECT_PATH, 'Project_Clinically_Aware_AI/dataset_setup/validation_images/')
# NOTE: This path assumes the challenge/metastasis data was processed into this folder structure.
# If you have it elsewhere, you may need to adjust this path.
METASTASIS_IMAGE_DIR = os.path.join(BASE_PROJECT_PATH, 'Challenge_processed_2D/images/')

# --- 2. Define the list of images we want to find ---
image_requests = [
    {'name': 'High-Quality_No-Tumor', 'folder': VALIDATION_IMAGE_DIR, 'prefix': 'Tr-no_', 'quality': 'high', 'count': 2},
    {'name': 'Low-Quality_No-Tumor',  'folder': VALIDATION_IMAGE_DIR, 'prefix': 'Tr-no_', 'quality': 'low',  'count': 1},
    {'name': 'High-Quality_Meningioma','folder': VALIDATION_IMAGE_DIR, 'prefix': 'Tr-me_', 'quality': 'high', 'count': 2},
    {'name': 'Low-Quality_Glioma',    'folder': VALIDATION_IMAGE_DIR, 'prefix': 'Tr-gl_', 'quality': 'low',  'count': 2},
    {'name': 'High-Quality_Pituitary','folder': VALIDATION_IMAGE_DIR, 'prefix': 'Tr-pi_', 'quality': 'high', 'count': 2},
    {'name': 'Metastasis_Tumor',      'folder': METASTASIS_IMAGE_DIR, 'prefix': '',       'quality': 'any',  'count': 3},
]

# --- 3. The Search Engine ---
found_images = []
for req in image_requests:
    print(f"  - Searching for {req['count']}x {req['name']}...")

    # Get all files from the target folder, shuffling them for variety
    all_files_in_folder = glob.glob(os.path.join(req['folder'], "*.jpg"))
    random.shuffle(all_files_in_folder)

    found_count = 0
    for image_path in all_files_in_folder:
        if found_count >= req['count']:
            break # Stop once we've found enough images for this request

        filename = os.path.basename(image_path)

        if req['prefix'] and not filename.startswith(req['prefix']):
            continue # Skip if the prefix doesn't match

        # Check image quality
        img_gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        sharpness = get_image_sharpness(img_gray)

        passes_quality_check = False
        if req['quality'] == 'high' and sharpness > 100:
            passes_quality_check = True
        elif req['quality'] == 'low' and sharpness < 40:
            passes_quality_check = True
        elif req['quality'] == 'any':
            passes_quality_check = True

        if passes_quality_check:
            # Create a descriptive new name for the downloaded file
            new_filename = f"test_{len(found_images) + 1}_{req['name']}.jpg"
            found_images.append({'new_name': new_filename, 'path': image_path})
            found_count += 1

# --- 4. Download all the found files ---
print(f"\n⬇️ Found {len(found_images)} total images. Preparing to download...")

if not found_images:
    print("⚠️ Could not find any suitable images. Please check the directory paths.")
else:
    for image_info in found_images:
        # !cp "{image_info['path']}" ./"{image_info['new_name']}"
        files.download(image_info['new_name'])
    print(f"\n✅ {len(found_images)} images downloaded! Check your browser's download bar.")
# Out:
# 🔎 Assembling a comprehensive test set of 12 images...
#   - Searching for 2x High-Quality_No-Tumor...
#   - Searching for 1x Low-Quality_No-Tumor...
#   - Searching for 2x High-Quality_Meningioma...
#   - Searching for 2x Low-Quality_Glioma...
#   - Searching for 2x High-Quality_Pituitary...
#   - Searching for 3x Metastasis_Tumor...
#
# ⬇️ Found 8 total images. Preparing to download...
# ✅ 8 images downloaded! Check your browser's download bar.

# %%
# ==============================================================================
#                 CELL 9: IMPROVEMENT 1 - DYNAMIC THRESHOLDS
# ------------------------------------------------------------------------------
# Purpose: To implement and simulate a more nuanced triage system using
#          different confidence thresholds for each prediction class.
# ==============================================================================
from collections import Counter
import pandas as pd

print("🚀 Implementing Improvement 1: Dynamic, Class-Specific Thresholds...")

# --- 1. Define the new, clinically-nuanced thresholds ---
# These are our new rules, reflecting different levels of caution.
triage_thresholds = {
    'no-tumor': 0.95,    # We must be very certain to classify a scan as normal.
    'meningioma': 0.90,  # A common, often less aggressive tumor.
    'pituitary': 0.92,   # Often well-defined, so we can require high confidence.
    'glioma': 0.88       # Can be diffuse and ambiguous, so we flag it even at a lower confidence.
}
print("   - New thresholds defined.")

# --- 2. Create the new, more advanced triage function ---
def get_triage_category_dynamic(prediction, thresholds):
    """Sorts a prediction into a queue using class-specific thresholds."""
    confidence = prediction['calibrated_confidence']
    class_name = prediction['class_name']

    # Get the specific threshold for the predicted class
    threshold = thresholds.get(class_name, 0.90) # Default to 0.90 if class is unknown

    if confidence > threshold:
        if class_name == 'no-tumor':
            return "Green Queue (Routine Review)", "Green"
        else:
            return "Red Queue (Urgent Review)", "Red"
    else:
        return "Yellow Queue (Standard Review)", "Yellow"

print("   - New dynamic triage function defined.")

# --- 3. Run the new simulation ---
print("🚀 Running new simulation with dynamic thresholds...")
dynamic_triage_counts = Counter()

for prediction in calibrated_predictions:
    triage_queue, _ = get_triage_category_dynamic(prediction, triage_thresholds)
    dynamic_triage_counts[triage_queue] += 1

# --- 4. Display the new results ---
total_predictions = len(calibrated_predictions)
results = []
for queue, count in dynamic_triage_counts.items():
    percentage = (count / total_predictions) * 100
    results.append({
        "Triage Queue": queue,
        "Number of Cases": count,
        "Percentage of Workload": f"{percentage:.2f}%"
    })

results_df = pd.DataFrame(results)

print("\n" + "="*60)
print("--- 📊 DYNAMIC THRESHOLD SIMULATION RESULTS ---")
print("="*60)
print(results_df.to_string(index=False))
# Out:
# 🚀 Implementing Improvement 1: Dynamic, Class-Specific Thresholds...
#    - New thresholds defined.
#    - New dynamic triage function defined.
# 🚀 Running new simulation with dynamic thresholds...
#
# ============================================================
# --- 📊 DYNAMIC THRESHOLD SIMULATION RESULTS ---
# ============================================================
#                   Triage Queue  Number of Cases Percentage of Workload
#      Red Queue (Urgent Review)              137                 52.29%
# Yellow Queue (Standard Review)              106                 40.46%
#   Green Queue (Routine Review)               19                  7.25%

# %%
# ==============================================================================
#            CELL 10: IMPROVEMENT 2 - CONTINUOUS URGENCY SCORE
# ------------------------------------------------------------------------------
# Purpose: To implement a sophisticated scoring system that calculates a
#          continuous urgency score based on multiple clinical factors.
# ==============================================================================
import pandas as pd

print("🚀 Implementing Improvement 2: Continuous Clinical Urgency Score...")

# --- 1. Define the weights for our scoring formula ---
# These weights determine the importance of each factor.
urgency_weights = {
    'confidence': 1.0,   # Higher confidence increases urgency (for tumors).
    'sharpness': -0.001, # Poor quality (low sharpness) slightly increases urgency.
    'size': 0.5          # Larger tumor size increases urgency.
}
print("   - Urgency weights defined.")

# --- 2. Create the new scoring function ---
def calculate_urgency_score(prediction, weights):
    """Calculates a raw urgency score based on a weighted formula."""

    # We only calculate urgency for potential tumors. Normal scans get a score of 0.
    if prediction['class_name'] == 'no-tumor':
        return 0.0

    # Extract features
    confidence = prediction['calibrated_confidence']
    sharpness = prediction['sharpness']
    size = get_box_area(prediction['box']) # get_box_area is defined in Cell 2

    # Calculate the raw weighted score
    raw_score = (confidence * weights['confidence'] +
                 sharpness * weights['sharpness'] +
                 size * weights['size'])

    return raw_score

print("   - Urgency score function defined.")

# --- 3. Run the new simulation ---
print("🚀 Calculating urgency scores for all test set cases...")
all_scores = []
for p in calibrated_predictions:
    raw_score = calculate_urgency_score(p, urgency_weights)
    all_scores.append({
        'class_name': p['class_name'],
        'raw_score': raw_score,
        'calibrated_confidence': p['calibrated_confidence'],
        'sharpness': p['sharpness'],
        'size': get_box_area(p['box'])
    })

# --- 4. Analyze the results ---
scores_df = pd.DataFrame(all_scores)

# To scale the scores from 1-100, we first filter out the "no-tumor" cases
tumor_scores = scores_df[scores_df['class_name'] != 'no-tumor']['raw_score']
min_score = tumor_scores.min()
max_score = tumor_scores.max()

# Scale the raw scores to a 1-100 range for easier interpretation
scores_df['Urgency Score (1-100)'] = scores_df['raw_score'].apply(
    lambda x: 1 + 99 * (x - min_score) / (max_score - min_score) if x > 0 else 0
)

print("\n" + "="*70)
print("--- 📊 URGENCY SCORE SIMULATION RESULTS ---")
print("="*70)
print("Summary statistics for the calculated Urgency Score (for tumor cases only):")
# Show summary stats for the final scaled scores of actual tumors
print(scores_df[scores_df['class_name'] != 'no-tumor']['Urgency Score (1-100)'].describe().round(2))

print("\n--- 📝 EXAMPLE CASE SCORES ---")
# Display the cases with the HIGHEST and LOWEST urgency scores
highest_urgency_cases = scores_df.nlargest(3, 'Urgency Score (1-100)')
lowest_urgency_cases = scores_df[scores_df['class_name'] != 'no-tumor'].nsmallest(3, 'Urgency Score (1-100)')

print("\n⬆️ Top 3 Highest Urgency Cases:")
print(highest_urgency_cases[['class_name', 'Urgency Score (1-100)']].round(2).to_string(index=False))

print("\n⬇️ Top 3 Lowest Urgency (but still tumor) Cases:")
print(lowest_urgency_cases[['class_name', 'Urgency Score (1-100)']].round(2).to_string(index=False))
# Out:
# 🚀 Implementing Improvement 2: Continuous Clinical Urgency Score...
#    - Urgency weights defined.
#    - Urgency score function defined.
# 🚀 Calculating urgency scores for all test set cases...
#
# ======================================================================
# --- 📊 URGENCY SCORE SIMULATION RESULTS ---
# ======================================================================
# Summary statistics for the calculated Urgency Score (for tumor cases only):
# count    209.00
# mean      83.81
# std       23.43
# min        0.00
# 25%       82.39
# 50%       94.89
# 75%       97.17
# max      100.00
# Name: Urgency Score (1-100), dtype: float64
#
# --- 📝 EXAMPLE CASE SCORES ---
#
# ⬆️ Top 3 Highest Urgency Cases:
# class_name  Urgency Score (1-100)
# meningioma                 100.00
# meningioma                  99.79
# meningioma                  99.75
#
# ⬇️ Top 3 Lowest Urgency (but still tumor) Cases:
# class_name  Urgency Score (1-100)
#  pituitary                    0.0
#  pituitary                    0.0
# meningioma                    0.0
